# %%
import torch
import audiobox_aesthetics.model.wavlm as wavlm_mod   # this is where GradMultiply lives

# JIT-friendly function: forward pass is pure Tensor math
@torch.jit.script
def _grad_multiply_jit(x: torch.Tensor, scale: float):
    return x                      # identity (we only care about inference!)

# shim object that mimics the old API (has an .apply method)
class _GradMultiplyShim:
    @staticmethod
    def apply(x, scale):
        return _grad_multiply_jit(x, scale)

# 🚨 IMPORTANT: patch *before* you create / trace the model
wavlm_mod.GradMultiply = _GradMultiplyShim

# %%
class AesWrapper(torch.nn.Module):
    def __init__(self, core):
        super().__init__()
        self.core = core
    def forward(self, wav: torch.Tensor) -> torch.Tensor:
        batch = {"wav": wav.unsqueeze(1)}          # [B,T] → [B,1,T]
        out = self.core(batch)
        return torch.stack([out["CE"], out["CU"], out["PC"], out["PQ"]], dim=-1)

# %%
model = AesMultiOutput.from_pretrained("facebook/audiobox-aesthetics").eval().to("cpu")
# … (wrapper definition) …
example = torch.randn(1, 16_000 * 10)
ts = torch.jit.trace(AesWrapper(model), example, strict=False)
ts.save("audiobox_aesthetics_ts.pt")          # ← now works

# %%
ts = torch.jit.load("audiobox_aesthetics_ts.pt").to("cuda")

# %%
x  = torch.randn(1, 16000 * 5, device="cuda")     # 5-second dummy audio
ts(x)

# %%
device = torch.device("cuda:0")          # or "cuda:1", …
ts = torch.jit.load("audiobox_aesthetics_ts.pt", map_location=device)
ts = ts.eval()                           # just a habit; avoids dropout, etc.

# %%
import torch

device = "cuda:0"                           # pick your GPU

ts = torch.jit.load("audiobox_aesthetics_ts.pt", map_location="cpu")
ts = ts.to(device)                          # <── this line fixes the error
ts = ts.eval()

x = torch.randn(1, 16_000 * 5, device=device)   # 5-s dummy audio
scores = ts(x)                                # OK: all tensors on cuda:0
print(scores)                                 # tensor([[CE, CU, PC, PQ]])

# %% [markdown]
# # Trace for CPU

# %%
import torch
from audiobox_aesthetics.model.aes import AesMultiOutput
import audiobox_aesthetics.model.wavlm as wavlm_mod

# --------------------------------------------------------------------------- #
# 1.  Gra​dMultiply shim  (unchanged)
@torch.jit.script
def _grad_multiply_jit(x: torch.Tensor, scale: float):
    return x
class _GradMultiplyShim:
    @staticmethod
    def apply(x, scale):
        return _grad_multiply_jit(x, scale)
wavlm_mod.GradMultiply = _GradMultiplyShim
# --------------------------------------------------------------------------- #

device = "cpu"
core   = AesMultiOutput.from_pretrained("facebook/audiobox-aesthetics") \
                       .to(device).eval()

# --------------------------------------------------------------------------- #
# 2.  Wrapper that *bakes in* de-zscoring
class AesWrapper(torch.nn.Module):
    def __init__(self, core):
        super().__init__()
        self.core = core

        # ---- pull the stats out of the original model ----------------------
        order = ["CE", "CU", "PC", "PQ"]
        means = [core.target_transform[s]["mean"] for s in order]
        stds  = [core.target_transform[s]["std"]  for s in order]

        # register as BUFFERS so TorchScript treats them as constants
        self.register_buffer("mean", torch.tensor(means, dtype=torch.float32))
        self.register_buffer("std",  torch.tensor(stds,  dtype=torch.float32))

    def forward(self, wav: torch.Tensor) -> torch.Tensor:
        # input wav shape  [B, T]  (16 kHz mono, -1..1)
        batch  = {"wav": wav.unsqueeze(1)}          # → [B,1,T]
        raw    = self.core(batch)                   # dict of z-scores
        z      = torch.stack([raw["CE"], raw["CU"], raw["PC"], raw["PQ"]], -1)
        return z * self.std + self.mean             # denorm inside the graph
# --------------------------------------------------------------------------- #

wrapper = AesWrapper(core).to(device)

# ----- trace or script ------------------------------------------------------
example = torch.randn(1, 16_000 * 10, device=device)   # 10-s dummy
ts = torch.jit.trace(wrapper, example, strict=False)    # or  torch.jit.script(wrapper)
ts.eval()
ts = torch.jit.freeze(ts)                              # optional but nice

ts.save("audiobox_aesthetics_ts_cpu.pt")
print("✅ TorchScript bundle with baked-in means/stds saved.")
# Out:
# ✅ TorchScript bundle with baked-in means/stds saved.

# %% [markdown]
# # TEST INFERENCE

# %%
import torch
ts = torch.jit.load("audiobox_aesthetics_ts_cpu.pt")
ts = ts.eval()

# %%
with torch.inference_mode():
    for _ in range(3):           # call repeatedly – no crash
        x  = torch.randn(1, 16000*10,device="cpu")
        print(ts(x))             # tensor([[CE, CU, PC, PQ]])
ts(x).shape
# Out:
# tensor([[2.3310, 4.8411, 2.0928, 4.7827]])
# tensor([[2.2362, 4.7066, 2.0517, 4.7879]])
# tensor([[2.1967, 4.3483, 2.1122, 4.6560]])
# torch.Size([1, 4])

# %% [markdown]
# # MAKE ONNX

# %%
import torch.onnx as onnx

dummy = torch.randn(1, 16000*10,device="cpu")

# 3. Export
onnx.export(
    ts,                      # the ScriptModule
    dummy,                   # example input
    "audiobox_aesthetics.onnx",
    export_params=True,      # store learned weights in the file
    opset_version=18,        # or whichever ONNX version you target
    input_names=["audio"],
    output_names=["scores"],
    dynamic_axes={
        "audio":  {1: "n_samples"},   # allow arbitrary length waveforms
    },
)
print("✅  ONNX export complete → audiobox_aesthetics.onnx")
# Out:
# ✅  ONNX export complete → audiobox_aesthetics.onnx

# %%
import onnxruntime as rt
dummy = torch.randn(1,16000*10,device="cpu")
sess = rt.InferenceSession("audiobox_aesthetics.onnx")
out = sess.run(None, {"audio": dummy.numpy()})[0]
print(torch.tensor(out)) # should match TorchScript output
# Out:
# 2025-06-22 01:07:36.556064347 [E:onnxruntime:, sequential_executor.cc:572 ExecuteKernel] Non-zero status code returned while running Where node. Name:'/Where' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/math/element_wise_ops.h:540 void onnxruntime::BroadcastIterator::Init(ptrdiff_t, ptrdiff_t) axis == 1 || axis == largest was false. Attempting to broadcast an axis by a dimension other than 1. 499 by 768
# ---------------------------------------------------------------------------
# RuntimeException                          Traceback (most recent call last)
# Cell In[104], line 4
#       2 dummy = torch.randn(1,16000*10,device="cpu")
#       3 sess = rt.InferenceSession("audiobox_aesthetics.onnx")
# ----> 4 out = sess.run(None, {"audio": dummy.numpy()})[0]
#       5 print(torch.tensor(out)) # should match TorchScript output
#
# File /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:273, in Session.run(self, output_names, input_feed, run_options)
#     271     output_names = [output.name for output in self._outputs_meta]
#     272 try:
# --> 273     return self._sess.run(output_names, input_feed, run_options)
#     274 except C.EPFail as err:
#     275     if self._enable_fallback:
#
# RuntimeException: [ONNXRuntimeError] : 6 : RUNTIME_EXCEPTION : Non-zero status code returned while running Where node. Name:'/Where' Status Message: /onnxruntime_src/onnxruntime/core/providers/cpu/math/element_wise_ops.h:540 void onnxruntime::BroadcastIterator::Init(ptrdiff_t, ptrdiff_t) axis == 1 || axis == largest was false. Attempting to broadcast an axis by a dimension other than 1. 499 by 768

# %%
import torch
model = torch.jit.load('audiobox_aesthetics_ts_cpu.pt')
print(model.graph)  # Examine operations
# Out:
# graph(%self : __torch__.___torch_mangle_3677.AesWrapper,
#       %wav.1 : Tensor):
#   %3713 : Tensor = prim::Constant[value= 5.0686  5.7363  3.1859  6.5750 [ CPUFloatType{4} ]]() # :0:0
#   %3711 : Tensor = prim::Constant[value= 1.9303  1.7567  1.8664  1.5147 [ CPUFloatType{4} ]]() # :0:0
#   %3700 : Tensor = prim::Constant[value={-0.0261768}]() # :0:0
#   %3699 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3691 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3690 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3686 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3685 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3677 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3676 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3672 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3671 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3663 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3662 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3658 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3657 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3649 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3648 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3644 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3643 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3638 : Tensor = prim::Constant[value={0.0137746}]() # :0:0
#   %3637 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3629 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3628 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3624 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3623 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3615 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3614 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3610 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3609 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3601 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3600 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3596 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3595 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3587 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3586 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3582 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3581 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3576 : Tensor = prim::Constant[value={0.0135231}]() # :0:0
#   %3575 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3567 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3566 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3562 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3561 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3553 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3552 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3548 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3547 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3539 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3538 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3534 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3533 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3525 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3524 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3520 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3519 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3514 : Tensor = prim::Constant[value={0.0137651}]() # :0:0
#   %3513 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3505 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3504 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3500 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3499 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3491 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3490 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3486 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3485 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3477 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3476 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3472 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3471 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3463 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3462 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3458 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3457 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3414 : str = prim::Constant[value="tbcl,l->btc"]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/functional.py:407:0
#   %3412 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3392 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3391 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3383 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3382 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3369 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3368 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3363 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3362 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3346 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3345 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3251 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3250 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3247 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3246 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3243 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3242 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3188 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3169 : Tensor = prim::Constant[value=-0.1521 -0.1521 -0.1521 -0.1521  0.4747  0.4747  0.4747  0.4747 [ CPUFloatType{8} ]]() # :0:0
#   %3168 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3138 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3137 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3129 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3128 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3115 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3114 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3109 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3108 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3092 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %3091 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2997 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2996 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2993 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2992 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2989 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2988 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2934 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2915 : Tensor = prim::Constant[value= 0.0332  0.0332  0.0332  0.0332  0.5335  0.5335  0.5335  0.5335 [ CPUFloatType{8} ]]() # :0:0
#   %2914 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2884 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2883 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2875 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2874 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2861 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2860 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2855 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2854 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2838 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2837 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2743 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2742 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2739 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2738 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2735 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2734 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2680 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2661 : Tensor = prim::Constant[value= 0.5657  0.5657  0.5657  0.5657  0.3149  0.3149  0.3149  0.3149 [ CPUFloatType{8} ]]() # :0:0
#   %2660 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2630 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2629 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2621 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2620 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2607 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2606 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2601 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2600 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2584 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2583 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2489 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2488 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2485 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2484 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2481 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2480 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2426 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2407 : Tensor = prim::Constant[value= 0.3651  0.3651  0.3651  0.3651  0.4915  0.4915  0.4915  0.4915 [ CPUFloatType{8} ]]() # :0:0
#   %2406 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2376 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2375 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2367 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2366 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2353 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2352 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2347 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2346 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2330 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2329 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2235 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2234 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2231 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2230 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2227 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2226 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2172 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2153 : Tensor = prim::Constant[value= 0.9136  0.9136  0.9136  0.9136  0.2832  0.2832  0.2832  0.2832 [ CPUFloatType{8} ]]() # :0:0
#   %2152 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2122 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2121 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2113 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2112 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2099 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2098 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2093 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2092 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2076 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %2075 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1981 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1980 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1977 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1976 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1973 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1972 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1918 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1899 : Tensor = prim::Constant[value= 0.9547  0.9547  0.9547  0.9547  0.4535  0.4535  0.4535  0.4535 [ CPUFloatType{8} ]]() # :0:0
#   %1898 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1868 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1867 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1859 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1858 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1845 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1844 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1839 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1838 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1822 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1821 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1727 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1726 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1723 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1722 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1719 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1718 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1664 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1645 : Tensor = prim::Constant[value= 1.1095  1.1095  1.1095  1.1095  0.5092  0.5092  0.5092  0.5092 [ CPUFloatType{8} ]]() # :0:0
#   %1644 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1614 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1613 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1605 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1604 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1591 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1590 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1585 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1584 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1568 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1567 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1473 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1472 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1469 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1468 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1465 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1464 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1410 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1391 : Tensor = prim::Constant[value= 0.7748  0.7748  0.7748  0.7748  0.4976  0.4976  0.4976  0.4976 [ CPUFloatType{8} ]]() # :0:0
#   %1390 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1360 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1359 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1351 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1350 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1337 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1336 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1331 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1330 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1314 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1313 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1219 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1218 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1215 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1214 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1211 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1210 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1157 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1138 : Tensor = prim::Constant[value= 0.7053  0.7053  0.7053  0.7053  0.5902  0.5902  0.5902  0.5902 [ CPUFloatType{8} ]]() # :0:0
#   %1137 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1107 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1106 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1098 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1097 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1084 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1083 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1078 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1077 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1061 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %1060 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %967 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %966 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %963 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %962 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %959 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %958 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %905 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %886 : Tensor = prim::Constant[value= 0.8871  0.8871  0.8871  0.8871  0.4261  0.4261  0.4261  0.4261 [ CPUFloatType{8} ]]() # :0:0
#   %885 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %855 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %854 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %846 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %845 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %832 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %831 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %826 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %825 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %809 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %808 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %715 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %714 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %711 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %710 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %707 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %706 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %653 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %634 : Tensor = prim::Constant[value= 0.9450  0.9450  0.9450  0.9450  0.3853  0.3853  0.3853  0.3853 [ CPUFloatType{8} ]]() # :0:0
#   %633 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %603 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %602 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %594 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %593 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %580 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %579 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %574 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %573 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %557 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %556 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %536 : float = prim::Constant[value=0.]()
#   %465 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %464 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %461 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %460 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %457 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %456 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %450 : str = prim::Constant[value="trunc"]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6182:0
#   %446 : float = prim::Constant[value=-inf]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5962:0
#   %416 : Tensor = prim::Constant[value={2}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:557:0
#   %410 : Tensor = prim::Constant[value={1}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:557:0
#   %408 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %389 : Tensor = prim::Constant[value= 0.9037  0.9037  0.9037  0.9037  0.9805  0.9805  0.9805  0.9805 [ CPUFloatType{8} ]]() # :0:0
#   %388 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %356 : Tensor = prim::Constant[value={12}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:527:0
#   %341 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %295 : Tensor = prim::Constant[value={2.30259}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %291 : Tensor = prim::Constant[value={80}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %278 : Tensor = prim::Constant[value={0}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:436:0
#   %276 : Tensor = prim::Constant[value={160}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:436:0
#   %3726 : Device = prim::Constant[value="cpu"]()
#   %237 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %236 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %202 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %201 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %195 : Tensor = prim::Constant[value={0}]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1426:0
#   %189 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %188 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %151 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %150 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %131 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %115 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %99 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %83 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %67 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %50 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %47 : str = prim::Constant[value="none"]()
#   %40 : float = prim::Constant[value=1.0000000000000001e-05]()
#   %39 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %38 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %27 : bool = prim::Constant[value=1]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %16 : Tensor = prim::Constant[value=<Tensor>]() # :0:0
#   %10 : bool = prim::Constant[value=0]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:147:0
#   %8 : NoneType = prim::Constant() # :0:0
#   %3 : int = prim::Constant[value=1]() # /tmp/ipykernel_466784/3932140254.py:39:0
#   %7 : int = prim::Constant[value=11]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:147:0
#   %18 : int = prim::Constant[value=5]() # :0:0
#   %20 : int = prim::Constant[value=0]() # :0:0
#   %31 : int = prim::Constant[value=6]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:63:0
#   %37 : int = prim::Constant[value=512]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2965:0
#   %52 : int = prim::Constant[value=2]() # :0:0
#   %169 : int = prim::Constant[value=9223372036854775807]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1169:0
#   %179 : int = prim::Constant[value=-1]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1170:0
#   %204 : int = prim::Constant[value=64]() # :0:0
#   %209 : int = prim::Constant[value=16]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %234 : int = prim::Constant[value=768]() # :0:0
#   %250 : int = prim::Constant[value=4]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:462:0
#   %284 : int = prim::Constant[value=80]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:444:0
#   %309 : int = prim::Constant[value=159]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:453:0
#   %372 : int = prim::Constant[value=12]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:548:0
#   %378 : int = prim::Constant[value=3]() # :0:0
#   %3442 : float = prim::Constant[value=2.]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/functional.py:1827:0
#   %3448 : float = prim::Constant[value=9.9999999999999998e-13]() # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5481:0
#   %4 : Tensor = aten::unsqueeze(%wav.1, %3) # /tmp/ipykernel_466784/3932140254.py:39:0
#   %wav0.1 : Tensor = aten::squeeze(%4, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:142:0
#   %padding_mask.1 : Tensor = aten::zeros_like(%wav0.1, %7, %8, %8, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:147:0
#   %input.1 : Tensor = aten::unsqueeze(%wav0.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1336:0
#   %19 : int[] = prim::ListConstruct(%18)
#   %21 : int[] = prim::ListConstruct(%20)
#   %22 : int[] = prim::ListConstruct(%3)
#   %24 : int[] = prim::ListConstruct(%20)
#   %input0.1 : Tensor = aten::_convolution(%input.1, %16, %8, %19, %21, %22, %10, %24, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %input1.1 : Tensor = aten::to(%input0.1, %31, %10, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:63:0
#   %output.1 : Tensor = aten::group_norm(%input1.1, %37, %38, %39, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2965:0
#   %input2.1 : Tensor = aten::type_as(%output.1, %input1.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:69:0
#   %input3.1 : Tensor = aten::gelu(%input2.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %53 : int[] = prim::ListConstruct(%52)
#   %54 : int[] = prim::ListConstruct(%20)
#   %55 : int[] = prim::ListConstruct(%3)
#   %57 : int[] = prim::ListConstruct(%20)
#   %input4.1 : Tensor = aten::_convolution(%input3.1, %50, %8, %53, %54, %55, %10, %57, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %input5.1 : Tensor = aten::gelu(%input4.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %69 : int[] = prim::ListConstruct(%52)
#   %70 : int[] = prim::ListConstruct(%20)
#   %71 : int[] = prim::ListConstruct(%3)
#   %73 : int[] = prim::ListConstruct(%20)
#   %input6.1 : Tensor = aten::_convolution(%input5.1, %67, %8, %69, %70, %71, %10, %73, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %input7.1 : Tensor = aten::gelu(%input6.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %85 : int[] = prim::ListConstruct(%52)
#   %86 : int[] = prim::ListConstruct(%20)
#   %87 : int[] = prim::ListConstruct(%3)
#   %89 : int[] = prim::ListConstruct(%20)
#   %input8.1 : Tensor = aten::_convolution(%input7.1, %83, %8, %85, %86, %87, %10, %89, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %input9.1 : Tensor = aten::gelu(%input8.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %101 : int[] = prim::ListConstruct(%52)
#   %102 : int[] = prim::ListConstruct(%20)
#   %103 : int[] = prim::ListConstruct(%3)
#   %105 : int[] = prim::ListConstruct(%20)
#   %input10.1 : Tensor = aten::_convolution(%input9.1, %99, %8, %101, %102, %103, %10, %105, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %input11.1 : Tensor = aten::gelu(%input10.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %117 : int[] = prim::ListConstruct(%52)
#   %118 : int[] = prim::ListConstruct(%20)
#   %119 : int[] = prim::ListConstruct(%3)
#   %121 : int[] = prim::ListConstruct(%20)
#   %input12.1 : Tensor = aten::_convolution(%input11.1, %115, %8, %117, %118, %119, %10, %121, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %input13.1 : Tensor = aten::gelu(%input12.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %133 : int[] = prim::ListConstruct(%52)
#   %134 : int[] = prim::ListConstruct(%20)
#   %135 : int[] = prim::ListConstruct(%3)
#   %137 : int[] = prim::ListConstruct(%20)
#   %input14.1 : Tensor = aten::_convolution(%input13.1, %131, %8, %133, %134, %135, %10, %137, %3, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %features.1 : Tensor = aten::gelu(%input14.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input15.1 : Tensor = aten::transpose(%features.1, %3, %52) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1191:0
#   %149 : int[] = prim::ListConstruct(%37)
#   %features0.1 : Tensor = aten::layer_norm(%input15.1, %149, %150, %151, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %156 : int = aten::size(%padding_mask.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1167:0
#   %157 : Tensor = prim::NumToTensor(%156) # :0:0
#   %159 : int = aten::size(%features0.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1167:0
#   %162 : Tensor = prim::NumToTensor(%159) # :0:0
#   %extra.1 : Tensor = aten::remainder(%157, %162) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1167:0
#   %165 : Tensor = aten::neg(%extra.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1169:0
#   %167 : int = aten::Int(%165) # :0:0
#   %171 : Tensor = aten::slice(%padding_mask.1, %20, %20, %169, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1169:0
#   %padding_mask0.1 : Tensor = aten::slice(%171, %3, %20, %167, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1169:0
#   %177 : int = aten::size(%padding_mask0.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1170:0
#   %180 : int[] = prim::ListConstruct(%177, %159, %179)
#   %padding_mask1.1 : Tensor = aten::view(%padding_mask0.1, %180) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1170:0
#   %padding_mask2.1 : Tensor = aten::all(%padding_mask1.1, %179, %10) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1171:0
#   %input16.1 : Tensor = aten::linear(%features0.1, %188, %189) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %192 : Tensor?[] = prim::ListConstruct(%padding_mask2.1)
#   %x.1 : Tensor = aten::index_put_(%input16.1, %192, %195, %10) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1426:0
#   %input17.1 : Tensor = aten::transpose(%x.1, %3, %52) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1428:0
#   %203 : int[] = prim::ListConstruct(%3)
#   %205 : int[] = prim::ListConstruct(%204)
#   %206 : int[] = prim::ListConstruct(%3)
#   %208 : int[] = prim::ListConstruct(%20)
#   %x0.1 : Tensor = aten::_convolution(%input17.1, %201, %202, %203, %205, %206, %10, %208, %209, %10, %10, %27, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/conv.py:370:0
#   %217 : Tensor = aten::slice(%x0.1, %20, %20, %169, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:94:0
#   %220 : Tensor = aten::slice(%217, %3, %20, %169, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:94:0
#   %input18.1 : Tensor = aten::slice(%220, %52, %20, %179, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:94:0
#   %x_conv.1 : Tensor = aten::gelu(%input18.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %x_conv0.1 : Tensor = aten::transpose(%x_conv.1, %3, %52) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1429:0
#   %input19.1 : Tensor = aten::add(%x.1, %x_conv0.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1430:0
#   %235 : int[] = prim::ListConstruct(%234)
#   %input20.1 : Tensor = aten::layer_norm(%input19.1, %235, %236, %237, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %query.1 : Tensor = aten::transpose(%input20.1, %20, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1438:0
#   %244 : int = aten::size(%query.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:511:0
#   %246 : int = aten::size(%query.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:511:0
#   %bsz.1 : Tensor = prim::NumToTensor(%246) # :0:0
#   %255 : Tensor = aten::arange(%244, %250, %8, %3726, %10) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:462:0
#   %258 : Tensor = aten::slice(%255, %20, %20, %169, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:462:0
#   %context_position.1 : Tensor = aten::unsqueeze(%258, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:462:0
#   %262 : Tensor = aten::unsqueeze(%255, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:463:0
#   %memory_position.1 : Tensor = aten::slice(%262, %3, %20, %169, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:463:0
#   %relative_positions.1 : Tensor = aten::sub(%memory_position.1, %context_position.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:464:0
#   %270 : Tensor = aten::gt(%relative_positions.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:436:0
#   %274 : Tensor = aten::to(%270, %250, %10, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:436:0
#   %277 : Tensor = aten::mul(%274, %276) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:436:0
#   %relative_buckets.1 : Tensor = aten::add(%277, %278, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:436:0
#   %relative_positions0.1 : Tensor = aten::abs(%relative_positions.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:437:0
#   %is_small.1 : Tensor = aten::lt(%relative_positions0.1, %284) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:444:0
#   %290 : Tensor = aten::to(%relative_positions0.1, %31, %10, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %292 : Tensor = aten::div(%290, %291) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %294 : Tensor = aten::log(%292) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %296 : Tensor = aten::div(%294, %295) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %299 : Tensor = aten::mul(%296, %291) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:447:0
#   %303 : Tensor = aten::to(%299, %250, %10, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:450:0
#   %relative_postion_if_large.1 : Tensor = aten::add(%303, %291, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:446:0
#   %315 : Tensor = aten::full_like(%relative_postion_if_large.1, %309, %8, %8, %8, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:453:0
#   %relative_postion_if_large0.1 : Tensor = aten::min(%relative_postion_if_large.1, %315) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:451:0
#   %322 : Tensor = aten::where(%is_small.1, %relative_positions0.1, %relative_postion_if_large0.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:456:0
#   %relative_position_bucket.1 : Tensor = aten::add_(%relative_buckets.1, %322, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:456:0
#   %input21.1 : Tensor = aten::to(%relative_position_bucket.1, %250, %20, %3726, %8, %10, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:468:0
#   %values.1 : Tensor = aten::embedding(%341, %input21.1, %179, %10, %10) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2551:0
#   %348 : int[] = prim::ListConstruct(%52, %20, %3)
#   %position_bias.1 : Tensor = aten::permute(%values.1, %348) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:472:0
#   %351 : Tensor = aten::unsqueeze(%position_bias.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:525:0
#   %353 : int[] = prim::ListConstruct(%246, %3, %3, %3)
#   %354 : Tensor = aten::repeat(%351, %353) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:526:0
#   %357 : Tensor = aten::mul(%bsz.1, %356) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:527:0
#   %359 : int = aten::Int(%357) # :0:0
#   %364 : int[] = prim::ListConstruct(%359, %244, %244)
#   %position_bias0.1 : Tensor = aten::view(%354, %364) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:527:0
#   %query_layer.1 : Tensor = aten::transpose(%query.1, %20, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:546:0
#   %369 : int = aten::size(%query_layer.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:547:0
#   %371 : int = aten::size(%query_layer.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:547:0
#   %373 : int[] = prim::ListConstruct(%369, %371, %372, %179)
#   %query_layer0.1 : Tensor = aten::view(%query_layer.1, %373) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:548:0
#   %379 : int[] = prim::ListConstruct(%20, %52, %3, %378)
#   %query_layer1.1 : Tensor = aten::permute(%query_layer0.1, %379) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:549:0
#   %382 : int = aten::size(%query_layer1.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:550:0
#   %384 : int = aten::size(%query_layer1.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:550:0
#   %386 : int = aten::size(%query_layer1.1, %52) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:550:0
#   %390 : Tensor = aten::linear(%query_layer1.1, %388, %389) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %395 : int[] = prim::ListConstruct(%382, %384, %386, %52, %250)
#   %396 : Tensor = aten::view(%390, %395) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:554:0
#   %398 : int[] = prim::ListConstruct(%179)
#   %401 : Tensor = aten::sum(%396, %398, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:553:0
#   %402 : Tensor = aten::sigmoid(%401) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:552:0
#   %403 : Tensor[] = aten::chunk(%402, %52, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:552:0
#   %gate_a.1 : Tensor, %gate_b.1 : Tensor = prim::ListUnpack(%403)
#   %409 : Tensor = aten::mul(%gate_b.1, %408) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:557:0
#   %412 : Tensor = aten::sub(%409, %410, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:557:0
#   %415 : Tensor = aten::mul(%gate_a.1, %412) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:557:0
#   %gate_a_1.1 : Tensor = aten::add(%415, %416, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:557:0
#   %421 : int[] = prim::ListConstruct(%359, %179, %3)
#   %422 : Tensor = aten::view(%gate_a_1.1, %421) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:559:0
#   %attn_mask_rel_pos.1 : Tensor = aten::mul(%422, %position_bias0.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:559:0
#   %428 : int[] = prim::ListConstruct(%179, %244, %244)
#   %attn_mask.1 : Tensor = aten::view(%attn_mask_rel_pos.1, %428) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:562:0
#   %tgt_len.1 : Tensor = prim::NumToTensor(%244) # :0:0
#   %433 : int = aten::size(%query.1, %52) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6138:0
#   %embed_dim.1 : Tensor = prim::NumToTensor(%433) # :0:0
#   %441 : Tensor = aten::zeros_like(%padding_mask2.1, %31, %8, %8, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5962:0
#   %key_padding_mask.1 : Tensor = aten::masked_fill_(%441, %padding_mask2.1, %446) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5962:0
#   %head_dim.1 : Tensor = aten::div(%embed_dim.1, %356, %450) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6182:0
#   %454 : int = aten::Int(%head_dim.1) # :0:0
#   %q.1 : Tensor = aten::linear(%query.1, %456, %457) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5712:0
#   %k.1 : Tensor = aten::linear(%query.1, %460, %461) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5712:0
#   %v.1 : Tensor = aten::linear(%query.1, %464, %465) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5712:0
#   %471 : int[] = prim::ListConstruct(%244, %359, %454)
#   %472 : Tensor = aten::view(%q.1, %471) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6271:0
#   %q0.1 : Tensor = aten::transpose(%472, %20, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6271:0
#   %476 : int = aten::size(%k.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6273:0
#   %479 : int[] = prim::ListConstruct(%476, %359, %454)
#   %480 : Tensor = aten::view(%k.1, %479) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6273:0
#   %k0.1 : Tensor = aten::transpose(%480, %20, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6273:0
#   %485 : int = aten::size(%v.1, %20) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6284:0
#   %488 : int[] = prim::ListConstruct(%485, %359, %454)
#   %489 : Tensor = aten::view(%v.1, %488) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6284:0
#   %v0.1 : Tensor = aten::transpose(%489, %20, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6284:0
#   %493 : int = aten::size(%k0.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6310:0
#   %497 : int[] = prim::ListConstruct(%246, %3, %3, %493)
#   %498 : Tensor = aten::view(%key_padding_mask.1, %497) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6319:0
#   %500 : int[] = prim::ListConstruct(%179, %372, %179, %179)
#   %502 : Tensor = aten::expand(%498, %500, %10) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6320:0
#   %505 : int[] = prim::ListConstruct(%359, %3, %493)
#   %key_padding_mask0.1 : Tensor = aten::reshape(%502, %505) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6321:0
#   %attn_mask0.1 : Tensor = aten::add(%attn_mask.1, %key_padding_mask0.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6326:0
#   %514 : int[] = prim::ListConstruct(%246, %372, %179, %493)
#   %attn_mask1.1 : Tensor = aten::view(%attn_mask0.1, %514) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6380:0
#   %520 : int[] = prim::ListConstruct(%246, %372, %244, %454)
#   %q1.1 : Tensor = aten::view(%q0.1, %520) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6382:0
#   %525 : int[] = prim::ListConstruct(%246, %372, %493, %454)
#   %k1.1 : Tensor = aten::view(%k0.1, %525) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6383:0
#   %v1.1 : Tensor = aten::view(%v0.1, %525) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6384:0
#   %attn_output.1 : Tensor = aten::scaled_dot_product_attention(%q1.1, %k1.1, %v1.1, %attn_mask1.1, %536, %10, %8, %10) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6386:0
#   %542 : int[] = prim::ListConstruct(%52, %20, %3, %378)
# ...
#   %3336 : Tensor = aten::mul(%bsz10.1, %tgt_len10.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6390:0
#   %3338 : int = aten::Int(%3336) # :0:0
#   %3340 : int[] = prim::ListConstruct(%3338, %3219)
#   %attn_output33.1 : Tensor = aten::view(%3333, %3340) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6390:0
#   %attn_output34.1 : Tensor = aten::linear(%attn_output33.1, %3345, %3346) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6393:0
#   %3351 : int = aten::size(%attn_output34.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6394:0
#   %3352 : int[] = prim::ListConstruct(%3143, %3145, %3351)
#   %input88.1 : Tensor = aten::view(%attn_output34.1, %3352) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:6394:0
#   %input89.1 : Tensor = aten::add(%query10.1, %input88.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1582:0
#   %3361 : int[] = prim::ListConstruct(%234)
#   %input90.1 : Tensor = aten::layer_norm(%input89.1, %3361, %3362, %3363, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %x23.1 : Tensor = aten::linear(%input90.1, %3368, %3369) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %x24.1 : Tensor = aten::to(%x23.1, %31, %10, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:157:0
#   %3378 : Tensor = aten::gelu(%x24.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:157:0
#   %input91.1 : Tensor = aten::type_as(%3378, %x24.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:157:0
#   %input92.1 : Tensor = aten::linear(%input91.1, %3382, %3383) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %input93.1 : Tensor = aten::add(%input90.1, %input92.1, %3) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py:1594:0
#   %3390 : int[] = prim::ListConstruct(%234)
#   %x25.1 : Tensor = aten::layer_norm(%input93.1, %3390, %3391, %3392, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %3409 : Tensor[] = prim::ListConstruct(%query.1, %query0.1, %query1.1, %query2.1, %query3.1, %query4.1, %query5.1, %query6.1, %query7.1, %query8.1, %query9.1, %query10.1, %x25.1)
#   %3411 : Tensor = aten::stack(%3409, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:170:0
#   %3413 : Tensor[] = prim::ListConstruct(%3411, %3412)
#   %audio_embed.1 : Tensor = aten::einsum(%3414, %3413, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/functional.py:407:0
#   %3419 : Tensor = aten::bitwise_not(%padding_mask2.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:182:0
#   %3420 : Tensor = aten::unsqueeze(%3419, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:182:0
#   %embed_mask.1 : Tensor = aten::type_as(%3420, %audio_embed.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:182:0
#   %3426 : Tensor = aten::mul(%audio_embed.1, %embed_mask.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:184:0
#   %3427 : int[] = prim::ListConstruct(%3)
#   %3430 : Tensor = aten::sum(%3426, %3427, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:184:0
#   %3432 : int[] = prim::ListConstruct(%3)
#   %3435 : Tensor = aten::sum(%embed_mask.1, %3432, %10, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:184:0
#   %3437 : Tensor = aten::clamp(%3435, %3, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:184:0
#   %input94.1 : Tensor = aten::div(%3430, %3437) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:184:0
#   %3443 : int[] = prim::ListConstruct(%179)
#   %3446 : Tensor = aten::linalg_vector_norm(%input94.1, %3442, %3443, %27, %8) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/functional.py:1827:0
#   %3449 : Tensor = aten::clamp_min(%3446, %3448) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5481:0
#   %denom.1 : Tensor = aten::expand_as(%3449, %input94.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5481:0
#   %input95.1 : Tensor = aten::div(%input94.1, %denom.1) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:5482:0
#   %input96.1 : Tensor = aten::linear(%input95.1, %3457, %3458) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3461 : int[] = prim::ListConstruct(%234)
#   %input97.1 : Tensor = aten::layer_norm(%input96.1, %3461, %3462, %3463, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input98.1 : Tensor = aten::gelu(%input97.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input99.1 : Tensor = aten::linear(%input98.1, %3471, %3472) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3475 : int[] = prim::ListConstruct(%234)
#   %input100.1 : Tensor = aten::layer_norm(%input99.1, %3475, %3476, %3477, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input101.1 : Tensor = aten::gelu(%input100.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input102.1 : Tensor = aten::linear(%input101.1, %3485, %3486) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3489 : int[] = prim::ListConstruct(%234)
#   %input103.1 : Tensor = aten::layer_norm(%input102.1, %3489, %3490, %3491, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input104.1 : Tensor = aten::gelu(%input103.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input105.1 : Tensor = aten::linear(%input104.1, %3499, %3500) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3503 : int[] = prim::ListConstruct(%234)
#   %input106.1 : Tensor = aten::layer_norm(%input105.1, %3503, %3504, %3505, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input107.1 : Tensor = aten::gelu(%input106.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %3515 : Tensor = aten::linear(%input107.1, %3513, %3514) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3517 : Tensor = aten::squeeze(%3515, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:190:0
#   %input108.1 : Tensor = aten::linear(%input95.1, %3519, %3520) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3523 : int[] = prim::ListConstruct(%234)
#   %input109.1 : Tensor = aten::layer_norm(%input108.1, %3523, %3524, %3525, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input110.1 : Tensor = aten::gelu(%input109.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input111.1 : Tensor = aten::linear(%input110.1, %3533, %3534) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3537 : int[] = prim::ListConstruct(%234)
#   %input112.1 : Tensor = aten::layer_norm(%input111.1, %3537, %3538, %3539, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input113.1 : Tensor = aten::gelu(%input112.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input114.1 : Tensor = aten::linear(%input113.1, %3547, %3548) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3551 : int[] = prim::ListConstruct(%234)
#   %input115.1 : Tensor = aten::layer_norm(%input114.1, %3551, %3552, %3553, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input116.1 : Tensor = aten::gelu(%input115.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input117.1 : Tensor = aten::linear(%input116.1, %3561, %3562) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3565 : int[] = prim::ListConstruct(%234)
#   %input118.1 : Tensor = aten::layer_norm(%input117.1, %3565, %3566, %3567, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input119.1 : Tensor = aten::gelu(%input118.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %3577 : Tensor = aten::linear(%input119.1, %3575, %3576) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3579 : Tensor = aten::squeeze(%3577, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:190:0
#   %input120.1 : Tensor = aten::linear(%input95.1, %3581, %3582) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3585 : int[] = prim::ListConstruct(%234)
#   %input121.1 : Tensor = aten::layer_norm(%input120.1, %3585, %3586, %3587, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input122.1 : Tensor = aten::gelu(%input121.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input123.1 : Tensor = aten::linear(%input122.1, %3595, %3596) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3599 : int[] = prim::ListConstruct(%234)
#   %input124.1 : Tensor = aten::layer_norm(%input123.1, %3599, %3600, %3601, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input125.1 : Tensor = aten::gelu(%input124.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input126.1 : Tensor = aten::linear(%input125.1, %3609, %3610) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3613 : int[] = prim::ListConstruct(%234)
#   %input127.1 : Tensor = aten::layer_norm(%input126.1, %3613, %3614, %3615, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input128.1 : Tensor = aten::gelu(%input127.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input129.1 : Tensor = aten::linear(%input128.1, %3623, %3624) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3627 : int[] = prim::ListConstruct(%234)
#   %input130.1 : Tensor = aten::layer_norm(%input129.1, %3627, %3628, %3629, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input131.1 : Tensor = aten::gelu(%input130.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %3639 : Tensor = aten::linear(%input131.1, %3637, %3638) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3641 : Tensor = aten::squeeze(%3639, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:190:0
#   %input132.1 : Tensor = aten::linear(%input95.1, %3643, %3644) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3647 : int[] = prim::ListConstruct(%234)
#   %input133.1 : Tensor = aten::layer_norm(%input132.1, %3647, %3648, %3649, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input134.1 : Tensor = aten::gelu(%input133.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input135.1 : Tensor = aten::linear(%input134.1, %3657, %3658) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3661 : int[] = prim::ListConstruct(%234)
#   %input136.1 : Tensor = aten::layer_norm(%input135.1, %3661, %3662, %3663, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input137.1 : Tensor = aten::gelu(%input136.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input138.1 : Tensor = aten::linear(%input137.1, %3671, %3672) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3675 : int[] = prim::ListConstruct(%234)
#   %input139.1 : Tensor = aten::layer_norm(%input138.1, %3675, %3676, %3677, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input140.1 : Tensor = aten::gelu(%input139.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %input141.1 : Tensor = aten::linear(%input140.1, %3685, %3686) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3689 : int[] = prim::ListConstruct(%234)
#   %input142.1 : Tensor = aten::layer_norm(%input141.1, %3689, %3690, %3691, %40, %27) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py:2910:0
#   %input143.1 : Tensor = aten::gelu(%input142.1, %47) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/activation.py:734:0
#   %3701 : Tensor = aten::linear(%input143.1, %3699, %3700) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/linear.py:125:0
#   %3706 : Tensor = aten::squeeze(%3701, %179) # /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py:190:0
#   %3707 : Tensor[] = prim::ListConstruct(%3517, %3579, %3641, %3706)
#   %z.1 : Tensor = aten::stack(%3707, %179) # /tmp/ipykernel_466784/3932140254.py:41:0
#   %3712 : Tensor = aten::mul(%z.1, %3711) # /tmp/ipykernel_466784/3932140254.py:42:0
#   %3715 : Tensor = aten::add(%3712, %3713, %3) # /tmp/ipykernel_466784/3932140254.py:42:0
#   return (%3715)

# %%
import torchaudio
device = "cpu"
# 3. Inference helper ---------------------------------------------------------
@torch.inference_mode()
def score(file_or_tensor):
    if isinstance(file_or_tensor, str):
        wav, sr = torchaudio.load(file_or_tensor)
        print(wav.shape, sr)
        if wav.size(0) > 1:                        # already mono? skip
            wav = wav.mean(dim=0, keepdim=True)    # [1, T]
        if sr != 16_000:                 # model expects 16 kHz
            wav = torchaudio.functional.resample(wav, sr, 16_000)
        #start = 0 #16_000 * 30
        #end = start + 16_000*20
        #wav = wav[:,start:end]
        #wav.to(device)
        print(wav.shape, 16_000)
    else:
        wav = file_or_tensor             # already a tensor

    scores = ts(wav.to(device))          # [B, T] → [B, 4] on GPU
    return scores
    return dict(zip(["CE", "CU", "PC", "PQ"], scores.squeeze(0).tolist()))

# --------------------------------------------------------------------------- #
#x = torch.randn(1, 16000*10, device="cuda:0")
x = "carbomb.mp3"
xscore = score(x)
xscore
# Out:
# torch.Size([2, 13174319]) 44100
# torch.Size([1, 4779799]) 16000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[85], line 28
#      25 # --------------------------------------------------------------------------- #
#      26 #x = torch.randn(1, 16000*10, device="cuda:0")
#      27 x = "carbomb.mp3"
# ---> 28 xscore = score(x)
#      29 xscore
#
# File /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[85], line 21, in score(file_or_tensor)
#      18 else:
#      19     wav = file_or_tensor             # already a tensor
# ---> 21 scores = ts(wav.to(device))          # [B, T] → [B, 4] on GPU
#      22 return scores
#      23 return dict(zip(["CE", "CU", "PC", "PQ"], scores.squeeze(0).tolist()))
#
# File /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py:1740, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1738     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1739 else:
# -> 1740     return self._call_impl(*args, **kwargs)
#
# File /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._call_impl(self, *args, **kwargs)
#    1746 # If we don't have any hooks, we want to skip the rest of the logic in
#    1747 # this function, and just call forward.
#    1748 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1749         or _global_backward_pre_hooks or _global_backward_hooks
#    1750         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1751     return forward_call(*args, **kwargs)
#    1753 result = None
#    1754 called_always_called_hooks = set()
#
# KeyboardInterrupt:

# %%
for stat in ["CE","CU","PC","PQ"]:
    norm_score = (xscore[stat] * model.target_transform[stat]['std']) +  model.target_transform[stat]['mean']
    print(stat, norm_score)
# Out:
# CE 6.492822108002901
# CU 7.496735419051647
# PC 6.63395175412178
# PQ 7.312182024731636

# %%
wav, sr = torchaudio.load("carbomb.mp3")
# print(wav.shape, sr)
# if wav.size(0) > 1:                        # already mono? skip
#     wav = wav.mean(dim=0, keepdim=True)    # [1, T]
# if sr != 16_000:                 # model expects 16 kHz
#     wav = torchaudio.functional.resample(wav, sr, 16_000)
# sr = 16_000
# wav = wav[:,:16_000*20]
# wav.shape

# %%
from audiobox_aesthetics import infer as aes_infer
aes_predictor = aes_infer.initialize_predictor()
transcription = aes_predictor.forward([{"path": wav, "sample_rate": sr}])[0]
transcription
# Out:
# {'CE': 6.288222312927246,
#  'CU': 7.438724517822266,
#  'PC': 6.5343337059021,
#  'PQ': 7.253620624542236}

# %%
# Inspect the transform for a single metric, e.g., 'PQ'
pq_transform = model.target_transform['PQ']
pq_mean = pq_transform['mean']
pq_std = pq_transform['std']

print(f"PQ Mean: {pq_mean}")
print(f"PQ Std: {pq_std}")

# You can store these values to use with your TorchScript output
INVERSE_NORM_CONSTANTS = {
    axis: {
        'mean': model.target_transform[axis]['mean'],
        'std': model.target_transform[axis]['std']
    }
    for axis in ["CE", "CU", "PC", "PQ"]
}
# Out:
# PQ Mean: 6.57505
# PQ Std: 1.51466

# %%
# 3) 10-s hop / window split, like infer.py (optional but recommended)
def split_to_windows(wav, sr=16_000, win=10, hop=10):
    step = hop * sr
    out  = []
    for st in range(0, wav.shape[-1], step):
        seg = wav[..., st:st + win * sr]
        if seg.shape[-1] < win * sr:          # right-pad with zeros
            seg = torch.nn.functional.pad(seg, (0, win*sr - seg.shape[-1]))
        out.append(seg)
    return torch.stack(out)

#wav = torch.randn(1, 16000*10*3, device="cuda:1")    # dummy 30-s clip
windows = split_to_windows(wav)                      # (N,1,T) on cuda
pred_z  = ts(windows.squeeze(1))                     # (N,4)  z-scores

# 4) inverse-normalize and length-average
pred = {}
for i, axis in enumerate(AXES):
    mean, std = stats[axis]["mean"], stats[axis]["std"]
    raw = pred_z[:, i] * std + mean                  # 1-10 scale
    pred[axis] = raw.mean().item()                   # same weight everywhere
print(json.dumps(pred, indent=2))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[31], line 14
#      12 #wav = torch.randn(1, 16000*10*3, device="cuda:1")    # dummy 30-s clip
#      13 windows = split_to_windows(wav)                      # (N,1,T) on cuda
# ---> 14 pred_z  = ts(windows.squeeze(1))                     # (N,4)  z-scores
#      16 # 4) inverse-normalize and length-average
#      17 pred = {}
#
# File /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py:1740, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1738     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1739 else:
# -> 1740     return self._call_impl(*args, **kwargs)
#
# File /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._call_impl(self, *args, **kwargs)
#    1746 # If we don't have any hooks, we want to skip the rest of the logic in
#    1747 # this function, and just call forward.
#    1748 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1749         or _global_backward_pre_hooks or _global_backward_hooks
#    1750         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1751     return forward_call(*args, **kwargs)
#    1753 result = None
#    1754 called_always_called_hooks = set()
#
# RuntimeError: The following operation failed in the TorchScript interpreter.
# Traceback of TorchScript, serialized code (most recent call last):
#   File "code/__torch__/___torch_mangle_1402.py", line 101, in forward
#     _32 = torch.slice(_31, -1, 1536, 2304)
#     _33 = torch.slice(_31, -1, 768, 1536)
#     _34 = torch.view(torch.slice(_31, -1, 0, 768), [_8, _19, _30])
#           ~~~~~~~~~~ <--- HERE
#     q = torch.transpose(_34, 0, 1)
#     _35 = torch.view(_33, [torch.size(_33, 0), _19, _30])
#
# Traceback of TorchScript, original code (most recent call last):
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/functional.py(6271): multi_head_attention_forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py(567): forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1730): _slow_forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1751): _call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1740): _wrapped_call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py(1571): forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1730): _slow_forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1751): _call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1740): _wrapped_call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py(1449): extract_features
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py(1415): forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1730): _slow_forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1751): _call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1740): _wrapped_call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/wavlm.py(1212): extract_features
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/audiobox_aesthetics/model/aes.py(162): forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1730): _slow_forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1751): _call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1740): _wrapped_call_impl
# /tmp/ipykernel_466784/474887763.py(26): forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1730): _slow_forward
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1751): _call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/nn/modules/module.py(1740): _wrapped_call_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/jit/_trace.py(1276): trace_module
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/jit/_trace.py(696): _trace_impl
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/torch/jit/_trace.py(1000): trace
# /tmp/ipykernel_466784/474887763.py(33): <module>
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3579): run_code
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3519): run_ast_nodes
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3336): run_cell_async
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/IPython/core/async_helpers.py(128): _pseudo_sync_runner
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3132): _run_cell
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/IPython/core/interactiveshell.py(3077): run_cell
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/zmqshell.py(549): run_cell
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/ipkernel.py(449): do_execute
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/kernelbase.py(778): execute_request
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/ipkernel.py(362): execute_request
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/kernelbase.py(437): dispatch_shell
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/kernelbase.py(534): process_one
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/kernelbase.py(545): dispatch_queue
# /usr/lib/python3.10/asyncio/events.py(80): _run
# /usr/lib/python3.10/asyncio/base_events.py(1909): _run_once
# /usr/lib/python3.10/asyncio/base_events.py(603): run_forever
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/tornado/platform/asyncio.py(205): start
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel/kernelapp.py(739): start
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/traitlets/config/application.py(1075): launch_instance
# /media/dadatron/squirrel/sa/venvs/sad310/lib/python3.10/site-packages/ipykernel_launcher.py(18): <module>
# /usr/lib/python3.10/runpy.py(86): _run_code
# /usr/lib/python3.10/runpy.py(196): _run_module_as_main
# RuntimeError: view size is not compatible with input tensor's size and stride (at least one dimension spans across two contiguous subspaces). Use .reshape(...) instead.

# %% [markdown]
# # torch.jit.script

# %%
import torch
import torch.nn.utils as nn_utils
import audiobox_aesthetics.model.wavlm as wavlm_mod
from audiobox_aesthetics.model.aes import AesMultiOutput

# ================================================================= #
# FINAL SET OF PATCHES AND WRAPPERS
# ================================================================= #

# PATCH 1: Fix the unscriptable FloorDiv operator (`//=`)
@torch.jit.script
def _bucket_relative_position_fixed(relative_positions: torch.Tensor, bidirectional: bool = True):
    # ... (full function code as before)
    num_buckets = 320; max_distance = 128; relative_buckets = torch.zeros_like(relative_positions, dtype=torch.long)
    if bidirectional:
        num_buckets = num_buckets // 2; relative_buckets += (relative_positions > 0).to(torch.long) * num_buckets
        relative_positions = torch.abs(relative_positions)
    else:
        relative_positions = -torch.min(relative_positions, torch.zeros_like(relative_positions))
    max_exact = num_buckets // 2; is_small = relative_positions < max_exact
    val_if_large = max_exact + (torch.log(relative_positions.float() / max_exact) / torch.log(torch.tensor(max_distance / max_exact)) * (num_buckets - max_exact)).to(torch.long)
    val_if_large = torch.min(val_if_large, torch.full_like(val_if_large, num_buckets - 1))
    relative_buckets += torch.where(is_small, relative_positions, val_if_large)
    return relative_buckets
print("Applying Patch 1: Fixing 'wavlm_mod._bucket_relative_position'...")
wavlm_mod._bucket_relative_position = _bucket_relative_position_fixed

# DEFINITIVE WRAPPER for PATCH 4
# This wrapper ensures the output of the MHA module is clean for the tracer.
class MHA_Tracer_Wrapper(torch.nn.Module):
    def __init__(self, mha_module):
        super().__init__()
        self.mha_module = mha_module

    def forward(self, q, k, v):
        # Call the original module which might return (tensor, None)
        output_tuple = self.mha_module(q, k, v)
        # We only return the first element, which is the attention output tensor.
        # This guarantees a JIT-traceable output.
        return output_tuple[0]

# ------------------------------------------------------------------ #
# Load model and create top-level wrapper
model = AesMultiOutput.from_pretrained("facebook/audiobox-aesthetics").eval()
class AesWrapper(torch.nn.Module):
    def __init__(self, core):
        super().__init__(); self.core = core
    def forward(self, wav: torch.Tensor) -> torch.Tensor:
        out = self.core({"wav": wav.unsqueeze(1)})
        return torch.stack([out[k] for k in ("CE", "CU", "PC", "PQ")], -1)
wrapper = AesWrapper(model).cpu().eval()

# PATCH 2: Find and delete ALL 'precision' attributes
print("\nApplying Patch 2: Searching for and deleting all 'precision' attributes...")
for name, module in wrapper.named_modules():
    if hasattr(module, 'precision'):
        print(f"  - Found and deleted 'precision' in submodule: {name}")
        delattr(module, 'precision')

# PATCH 3: Remove all weight_norm hooks
print("\nApplying Patch 3: Removing all 'weight_norm' hooks...")
for name, module in wrapper.named_modules():
    try:
        nn_utils.remove_weight_norm(module)
    except ValueError:
        continue
print("  - Finished removing weight_norm hooks.")

# HYBRID PATCH 4: Pre-trace the problematic MultiheadAttention using the clean wrapper
print("\nApplying Hybrid Patch 4: Pre-tracing 'MultiheadAttention' submodules via a wrapper...")
for name, module in list(wrapper.named_modules()):
    if isinstance(module, wavlm_mod.MultiheadAttention):
        print(f"  - Wrapping and tracing submodule: {name}")
        embed_dim = module.embed_dim; kdim = module.kdim if module.kdim is not None else embed_dim
        vdim = module.vdim if module.vdim is not None else embed_dim
        q = torch.randn(10, 1, embed_dim); k = torch.randn(10, 1, kdim); v = torch.randn(10, 1, vdim)
        
        # 1. Create an instance of our clean wrapper
        tracer_wrapper = MHA_Tracer_Wrapper(module.eval())
        
        # 2. Trace the WRAPPER, not the original module
        traced_submodule = torch.jit.trace(tracer_wrapper, (q, k, v))
        
        # 3. Replace the original module with the new, traced, clean-output module
        path = name.split('.'); parent = wrapper
        for p in path[:-1]:
            parent = getattr(parent, p)
        setattr(parent, path[-1], traced_submodule)
        print(f"  - Replaced '{name}' with its traced version.")

# ================================================================= #
# FINAL SCRIPTING ATTEMPT
# ================================================================= #
@torch.jit.script
def _gradmul(x: torch.Tensor, scale: float): return x
class _GradMulShim:
    @staticmethod
    def apply(x, scale): return _gradmul(x, scale)
wavlm_mod.GradMultiply = _GradMulShim
model.apply(lambda m: setattr(m, "grad_mult", 0.0) if hasattr(m, "grad_mult") else None)

print("\nScripting model...")
ts_portable = torch.jit.script(wrapper)
ts_portable.eval()

ts_portable = torch.jit.freeze(ts_portable)
ts_portable.save("audiobox_aesthetics_ts_portable.pt")
print("\n\n✅✅✅ VICTORY! ✅✅✅\nPortable TorchScript saved successfully as audiobox_aesthetics_ts_portable.pt")

# %%
import torch, audiobox_aesthetics.model.wavlm as wavlm_mod
from audiobox_aesthetics.model.aes import AesMultiOutput

# ------------------------------------------------------------------ #
# 0.  TorchScript-friendly GradMultiply (identity in forward pass)
@torch.jit.script
def _gradmul(x: torch.Tensor, scale: float):   return x
class _GradMulShim:
    @staticmethod
    def apply(x, scale):   return _gradmul(x, scale)
wavlm_mod.GradMultiply = _GradMulShim
# ------------------------------------------------------------------ #

# 1.  Load the model from the HF hub (**CPU**)
model = AesMultiOutput.from_pretrained("facebook/audiobox-aesthetics").eval()

# 2.  Disable gradient scaling (training-only feature)
model.apply(lambda m: setattr(m, "grad_mult", 0.0) if hasattr(m, "grad_mult") else None)

# 3.  Thin wrapper → tensor in / tensor out
class AesWrapper(torch.nn.Module):
    def __init__(self, core):
        super().__init__(); self.core = core
    def forward(self, wav: torch.Tensor) -> torch.Tensor:
        out = self.core({"wav": wav.unsqueeze(1)})           # [B,T] → [B,1,T]
        return torch.stack([out[k] for k in ("CE","CU","PC","PQ")], -1)
wrapper = AesWrapper(model).cpu()
wrapper.eval()                          # ← important

# 4.  Trace on CPU  ➜  freeze  ➜  save
example = torch.randn(1, 16_000 * 10)          # 10-s dummy audio
ts = torch.jit.trace(wrapper, example, strict=False)
ts.eval()                               # usually redundant but explicit

ts = torch.jit.freeze(ts)                      # removes autograd metadata
ts.save("audiobox_aesthetics_ts.pt")
print("✅  portable TorchScript saved as audiobox_aesthetics_ts.pt")

# %%
ts = torch.jit.load("audiobox_aesthetics_ts.pt").to("cuda:1").eval()
x  = torch.randn(1, 16_000*10, device="cuda:1")
print(ts(x))                                # runs every call
